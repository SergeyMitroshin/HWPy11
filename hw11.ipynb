# %% [markdown]
# Задание: f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %%
import numpy as np
from sympy import *
from sympy.plotting import plot
x=Symbol('x')
f = -12*x**4*sin(cos(x)) - 18*x**3+5*x**2 + 10*x - 30

def func(x):
    return -12 * x**4 * np.sin(np.cos(x)) - 18 * x**3 + 5 * x**2 + 10 * x - 30

# %%
plot (f,(x, -300, 300)) # график в диапазоне  (-100 100)
plot (f,(x, -100, 100)) # график в диапазоне  (-100 100)

# %%
plot(f, (x, -12,12)) # график в диапазоне  (-12 12)
plot(f, (x, -1.5, 2.4)) # график в диапазоне  (-1.5 2.4)

# %% [markdown]
# Исследуем по частям:

# %%
f2 = -12*x**4*sin(cos(x))
plot (f2, (x, -100, 100))
f3 = - 18*x**3+5*x**2 + 10*x - 30
plot (f3, (x, -100, 100))

# %% [markdown]
# Вывод: Отчетливо виден периодический характер функции с нарастанием амплитуды по мере
# отклонения от начала координат. Старший член -12x*4*sin(cos(x)) определяет
# периодический характер и вносит максимальный вклад в амплитуду. Количество корней
# и экстремумов (вершин) бесконечно, следовательно вычисление конкретных значений
# актуально в определенном интервале значений х (в задании не определено). Дальнейшие вычисления выполняем в диапазоне значений x от -10 до 10.

# %%
solveset(f, x) # корни (sympy)
# Out:
# ConditionSet(x, Eq(-12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30, 0), Complexes)

# %%
nsolve((f,), (x,), (0,))
# Out:
# Matrix([[-1.33896663927711]])

# %%
def bisection(f, lhs, rhs, eps=1e-6):

  mid = (lhs + rhs) / 2

  while abs(lhs - rhs) > eps:
    mid = (lhs + rhs) / 2

    if f(lhs) * f(mid) > 0: # f(lhs) > 0 and f(mid) > 0 or f(lhs) < 0 and f(mid) < 0
      lhs = mid
    else:
      rhs = mid
      
  return mid

# %% [markdown]
# Вычисляем корни методом bisection :

# %%
bisection(func, -12, -8)
# Out:
# -11.133769035339355

# %%
bisection(func, -8, -6)
# Out:
# -7.650622367858887

# %%
bisection(func, -6, -2)
# Out:
# -5.0268659591674805

# %%
bisection(func, 0, 3)
# Out:
# -1.3389673233032227

# %% [markdown]
# Значение корня, вычисленное методом bisection практически совпадает со значением,
# вычисленным с помощью sympy.

# %%
bisection(func, 0, 3)
# Out:
# 2.2730562686920166

# %%
bisection(func, 3, 5)
# Out:
# 4.383522987365723

# %%
bisection(func, 5, 10)
# Out:
# 8.035164475440979

# %%
bisection(func, 10, 12)
# Out:
# 10.860650062561035

# %% [markdown]
# f(x)>0 на инвервалах x:
#     от -11.133769035339355 до -7.650622367858887
#     от -5.0268659591674805 до -1.3389673233032227
#     от 2.2730562686920166  до 4.383522987365723
#     от 8.035164475440979 до 10.860650062561035
# f(x)<0 на интервалах x:
#     от -7.650622367858887 до -5.0268659591674805
#     от -1.3389673233032227 до 2.2730562686920166
#     от 4.383522987365723 до 8.035164475440979

# %% [markdown]
# Вычисляем 1 производную и строим её график:

# %%
df = diff(f)
plot (df,(x, -10, 10)) # график производной в диапазоне  (-10 10) 
df
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
def difer(x):
    return 12*𝑥**4*np.sin(𝑥)*np.cos(np.cos(𝑥))-48*𝑥**3*np.sin(np.cos(𝑥))-54*𝑥**2+10*𝑥+10

# %%
Вычисляем корни производной (координаты x эксремумов) функции f(x) методом bisection :

# %%
bisection(difer, -9, -6)
# Out:
# -6.831369638442993

# %%
bisection(difer, -6, -1)
# Out:
# -4.167783617973328

# %%
bisection(difer, -1, 0)
# Out:
# -0.39267635345458984

# %%
bisection(difer, 0, 1)
# Out:
# 0.4545736312866211

# %%
bisection(difer, 1, 2)
# Out:
# 1.700606346130371

# %%
bisection(difer, 2, 4)
# Out:
# 3.819310188293457

# %%
bisection(difer, 4, 8)
# Out:
# 7.001030921936035

# %% [markdown]
# В диапазоне значений x от -10 до 10
# f(x) растет на инвервалах x:
#     от -6.831369638442993 до -4.167783617973328
#     от -0.39267635345458984 до 0.4545736312866211
#     от 1.700606346130371 до 3.819310188293457
#     от 7.001030921936035 до 10
#
# f(x) убывает на инвервалах x:
#     от -10 до -6.831369638442993
#     от -4.167783617973328 до -0.39267635345458984
#     от 0.4545736312866211 до 1.700606346130371
#     от 3.819310188293457 до 7.001030921936035

# %% [markdown]
# Вычисляем координаты найденных экстремумов f(x) диапазоне значений x от -10 до 10

# %%
func(-6.831369638442993)
# Out:
# -25610.509681023632

# %%
func(-4.167783617973328)
# Out:
# 3111.363238735934

# %%
func(-0.39267635345458984)
# Out:
# -32.29357993644447

# %%
func(0.4545736312866211)
# Out:
# -26.512722365036925

# %%
func(1.700606346130371)
# Out:
# -74.10629308597034

# %%
func(3.819310188293457)
# Out:
# 872.255770290347

# %%
func(7.001030921936035)
# Out:
# -25610.509681023632
